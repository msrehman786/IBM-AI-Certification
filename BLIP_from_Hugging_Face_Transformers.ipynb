# %% [markdown]
# <a href="https://colab.research.google.com/github/msrehman786/IBM-AI-Certification/blob/main/BLIP_from_Hugging_Face_Transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of how to use BLIP for image captioning in Python

# %%
# Install the transformers library
# !pip install transformers pillow torch torchvision torchaudio
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

# %%
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# Load an image
image = Image.open(r"/content/MZRImage.jpeg")

# Prepare the image
inputs = processor(image, return_tensors="pt")

# Generate captions
outputs = model.generate(**inputs)
caption = processor.decode(outputs[0],skip_special_tokens=True)

print("Generated Caption:", caption)
# Out:
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# /usr/local/lib/python3.13/dist-packages/transformers/generation/utils.py:1676: UserWarning: Using the model-agnostic default `max_length` (=21) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Generated Caption: a young boy with a grey shirt and tie

# %% [markdown]
# Visual Question Answering
#
# The BLIP image-captioning model can process an image together with a text prompt to generate descriptive responses. It is well suited for applications where richer image descriptions are preferred.By learning the relationships between visual content and natural language, the model can generate meaningful captions that summarize the overall content and context of an image.

# %%
# Install required libraries
# !pip install transformers pillow torch torchvision torchaudio

# %%
# Import required modules
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

# Load BLIP processor and model (captioning model — treats the "question" as a caption prefix )
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large")

# Load image from URL
img_url = "https://storage.googleapis.com/sfr-vision-language-research/BLIP/demo.jpg"
image = Image.open(requests.get(img_url, stream=True).raw).convert("RGB")

# Define question about the image
question = "What is in the image?"

# Prepare both image + question as input
inputs = processor(image, question, return_tensors="pt")

# Generate answer
outputs = model.generate(**inputs)

# Decode output into readable text
answer = processor.decode(outputs[0], skip_special_tokens=True)

# Print final answer
print("Answer:", answer)
# Out:
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.60k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 1.88GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/616 [00:00<?, ?it/s]
# /usr/local/lib/python3.13/dist-packages/transformers/generation/utils.py:1676: UserWarning: Using the model-agnostic default `max_length` (=27) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Answer: what is in the image? a woman and her dog on the beach

# %% [markdown]
# Using the BLIP VQA Model
#
# BLIP also provides dedicated models for Visual Question Answering (VQA), such as Salesforce/blip-vqa-base, which are specifically fine-tuned to answer questions about an image. While the preceding example uses the image-captioning model to generate more descriptive responses, the following example demonstrates how to use a task-specific VQA model to generate concise answers to image-related questions.
#
# The BLIP VQA model is fine-tuned for Visual Question Answering tasks. It is optimized to provide concise and accurate answers to specific questions about an image.It is designed to understand an image and a user’s question, enabling it to generate concise, context-aware answers.

# %%
# Install required libraries
# !pip install transformers pillow torch torchvision torchaudio

# %%
# Import required modules
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForQuestionAnswering

# Load the BLIP VQA processor and model
processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")
model = BlipForQuestionAnswering.from_pretrained("Salesforce/blip-vqa-base")

# Load image from URL
img_url = "https://storage.googleapis.com/sfr-vision-language-research/BLIP/demo.jpg"
image = Image.open(requests.get(img_url, stream=True).raw).convert("RGB")

# Define a question about the image
question = "What dog breed is shown in the image?"

# Prepare the inputs
inputs = processor(image, question, return_tensors="pt")

# Generate the answer
outputs = model.generate(**inputs)

# Decode the output
answer = processor.decode(outputs[0], skip_special_tokens=True)

print("Answer:", answer)
# Out:
# Loading weights:   0%|          | 0/788 [00:00<?, ?it/s]
# Answer: lab
